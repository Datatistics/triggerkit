# %% [raw]
# ---
# description: Running the system
# output-file: app.html
# title: app
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(main)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/app.py#L124){target="_blank" style="float:right; font-size:smaller"}
#
# ### main
#
# >      main (args=None)
#
# *Main entry point for the application.
#
#    **Args:**
#
# • `args`: Optional list of command line argument strings, or parsed args object.
#
#            If None, will parse from command line.*
