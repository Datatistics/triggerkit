# %% [raw]
# ---
# description: Fill in a module description here
# output-file: jobs.html
# title: jobs
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(create)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L49){target="_blank" style="float:right; font-size:smaller"}
#
# ### create
#
# >      create (view_name:str, action_names:Union[str,List[str]],
# >              job_name:Optional[str]=None, executor:str='default')
#
# *Create a job function that fetches data from a view and runs specified actions.
#
# Args:
#     view_name: Name of the registered view
#     action_names: Name or list of names of registered actions
#     job_name: Optional name for the job
#     executor: Name of the executor to use ('default' for thread pool, 'processpool' for process pool)
#
# Returns:
#     Job function*

# %%
#| echo: false
#| output: asis
show_doc(schedule_jobs)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L218){target="_blank" style="float:right; font-size:smaller"}
#
# ### schedule_jobs
#
# >      schedule_jobs (config:Dict[str,Any])
#
# *Schedule jobs based on TOML configuration.
#
# Args:
#     config: Dictionary containing configuration sections
#
# Returns:
#     None*

# %%
#| echo: false
#| output: asis
show_doc(create_job_from_view)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L278){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_job_from_view
#
# >      create_job_from_view (data, config, context)
#
# *Create new jobs from views that have job configuration.*

# %%
#| echo: false
#| output: asis
show_doc(remove_job)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L472){target="_blank" style="float:right; font-size:smaller"}
#
# ### remove_job
#
# >      remove_job (job_id:str)
#
# *Remove a scheduled job.
#
# Args:
#     job_id: Job ID to remove
#
# Returns:
#     Dictionary with operation result*

# %%
#| echo: false
#| output: asis
show_doc(resume_job)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L450){target="_blank" style="float:right; font-size:smaller"}
#
# ### resume_job
#
# >      resume_job (job_id:str)
#
# *Resume a paused job.
#
# Args:
#     job_id: Job ID to resume
#
# Returns:
#     Dictionary with operation result*

# %%
#| echo: false
#| output: asis
show_doc(pause_job)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L428){target="_blank" style="float:right; font-size:smaller"}
#
# ### pause_job
#
# >      pause_job (job_id:str)
#
# *Pause a scheduled job.
#
# Args:
#     job_id: Job ID to pause
#
# Returns:
#     Dictionary with operation result*

# %%
#| echo: false
#| output: asis
show_doc(get_job_info)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L395){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_job_info
#
# >      get_job_info (job_id:Optional[str]=None)
#
# *Get information about scheduled jobs.
#
# Args:
#     job_id: Optional job ID to get specific job info
#
# Returns:
#     Dictionary with job information*

# %%
#| echo: false
#| output: asis
show_doc(run_scheduler)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L371){target="_blank" style="float:right; font-size:smaller"}
#
# ### run_scheduler
#
# >      run_scheduler ()
#
# *Run the scheduler in the background.
#
# Returns:
#     None*
