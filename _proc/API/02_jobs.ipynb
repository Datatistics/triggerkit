# %% [raw]
# ---
# description: Fill in a module description here
# output-file: jobs.html
# title: Jobs
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(create)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### create
#
# >      create (view_name:str, action_names:Union[str,List[str]],
# >              job_name:Optional[str]=None)
#
# *Create a job function that fetches data from a view and runs specified actions.
#
# Args:
#     view_name: Name of the registered view
#     action_names: Name or list of names of registered actions
#     job_name: Optional name for the job
#
# Returns:
#     Job function*

# %%
#| echo: false
#| output: asis
show_doc(schedule_jobs)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### schedule_jobs
#
# >      schedule_jobs (config:Dict[str,Any])
#
# *Schedule jobs based on TOML configuration.
#
# Args:
#     config: Dictionary containing configuration sections
#
# Returns:
#     None*

# %%
#| echo: false
#| output: asis
show_doc(run_scheduler)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/jobs.py#L121){target="_blank" style="float:right; font-size:smaller"}
#
# ### run_scheduler
#
# >      run_scheduler ()
#
# *Run the scheduler loop.*
