# %% [raw]
# ---
# description: Working with Snowflake
# output-file: snowflake.html
# title: snowflake
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(register_view)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/snowflake.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### register_view
#
# >      register_view (name:str, query:str,
# >                     metadata:Optional[Dict[str,Any]]=None)
#
# *Register a Snowflake view with the system.
#
# Args:
#     name: Name of the view
#     query: SQL query or view name to fetch datay
#     metadata: Additional metadata about the view
#
# Returns:
#     None*

# %%
#| echo: false
#| output: asis
show_doc(connect)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/snowflake.py#L39){target="_blank" style="float:right; font-size:smaller"}
#
# ### connect
#
# >      connect (config:Dict[str,Any])
#
# *Establish connection to Snowflake.
#
# Args:
#     config: Dictionary containing Snowflake connection parameters
#
# Returns:
#     Snowflake connection object*

# %%
#| echo: false
#| output: asis
show_doc(query)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/snowflake.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### query
#
# >      query (view_name:str)
#
# *Execute a query for a registered view and return results.
#
# Args:
#     view_name: Name of the registered view
#
# Returns:
#     List of result rows as dictionaries*
