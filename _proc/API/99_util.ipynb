# %% [raw]
# ---
# description: Shared Utilities and Information
# output-file: util.html
# title: util
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(load_config)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/util.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_config
#
# >      load_config (config_path:str)
#
# *Load configuration from TOML file with environment variable interpolation.
#
# Args:
#     config_path: Path to TOML config file
#
# Returns:
#     Dictionary containing configuration sections with env vars expanded*
