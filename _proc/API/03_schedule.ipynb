# %% [raw]
# ---
# description: Fill in a module description here
# output-file: schedule.html
# title: Jobs
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/schedule.py#L9){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(run_scheduler)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/schedule.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### run_scheduler
#
# >      run_scheduler ()
#
# *Run the scheduler loop.*
