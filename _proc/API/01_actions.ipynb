# %% [raw]
# ---
# description: Definiting actions, how to register them, etc.
# output-file: actions.html
# title: Actions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(register)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/actions.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### register
#
# >      register (name:str, description:Optional[str]=None)
#
# *Register a function as an action in the global registry.
#
# Args:
#     name: Unique identifier for the action
#     description: Optional description of what the action does
#
# Returns:
#     Decorator function that registers the decorated function
#
# Raises:
#     ValueError: If an action with the same name already exists*

# %%
#| echo: false
#| output: asis
show_doc(get_info)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/actions.py#L58){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_info
#
# >      get_info (name:str)
#
# *Get detailed information about a specific action.*

# %%
#| echo: false
#| output: asis
show_doc(list_available)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/actions.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### list_available
#
# >      list_available ()
#
# *List all registered actions with their descriptions.*

# %%
#| echo: false
#| output: asis
show_doc(run)
# Out:
# ---
#
# [source](https://github.com/Datatistics/triggerkit/blob/main/triggerkit/actions.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### run
#
# >      run (action_name:str, data:List[Dict[str,Any]])
#
# *Run a registered action with the provided data.
#
# Args:
#     action_name: Name of the registered action
#     data: Data to pass to the action
#
# Returns:
#     Result of the action*
